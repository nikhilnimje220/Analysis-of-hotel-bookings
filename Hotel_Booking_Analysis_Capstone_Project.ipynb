# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilnimje220/Analysis-of-hotel-bookings/blob/master/Hotel_Booking_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# ## <b>This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# ## <b> Explore and analyze the data to discover important factors that govern the bookings. </b>

# %%
Image

# %% [markdown]
# **We will try to answer the following Question:**

# %% [markdown]
# 1) What is the percentage of booking changes made by the customer?
#
# 2) Which type of food is mostly preferred by the guests?
#
# 3) What is the percentage of cancellation?
#
# 4) What is preferred stay in each hotel?
#
# 5) Visualizing proportion of booking cancellations wise bookings.
#
# 6) Market segment wise bookings
#
# 7) From where the most guests are coming ?
#
# 8) which channel is mostly used for early booking of hotels?
#
# 9) which is the busiest month for hotels?
#
# 10) Which type of hotel is mostly prefered by the guests?
#
# 11) Which hotel has high chance that its customer will return for another stay?
#
# 12) Which hotel has longer waiting time?
#
# 13) What is the percentage distribution of required car parking spaces?
#
# 14) which hotel seems to make more revenue?
#
# 15) Which year had the highest bookings?

# %% [markdown]
# **Importing Essential Libraries**

# %%
# Importing all import python libries
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Mounting Drive**

# %%
# Mounting drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **CSV File Location**

# %%
# Importing data
hotel_df = pd.read_csv("/content/Hotel Bookings.csv")

# %% [markdown]
# **Data Exploration**

# %%
# Taking a look to Data
hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
hotel_df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
hotel_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df1 = hotel_df.copy()

# %%
# columns name list
print(list(df1.columns))
# Out:
# ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date']

# %%
# converting object type to datetime
df1['reservation_status_date'] = pd.to_datetime(df1['reservation_status_date'], format = '%Y-%m-%d')

# %% [markdown]
# **Cleaning data**
#
# Cleaning data is crucial step before EDA as it will remove the ambigous data that can affect the outcome of EDA.

# %%
#dropping the duplicate rows
df1= df1.drop_duplicates()

# %%
# data set reduced
df1.shape
# Out:
# (87396, 32)

# %%
#checking for Null Values
df1.isna().sum().sort_values(ascending=False)[:6].reset_index().rename(columns={'index':'Columns',0:'Null values'})
# Out:
#               Columns  Null values
# 0             company        82137
# 1               agent        12193
# 2             country          452
# 3            children            4
# 4  reserved_room_type            0
# 5  assigned_room_type            0

# %%
# Visulaizing null values through heatmap.
plt.figure(figsize=(25, 10))
sns.heatmap(df1.isnull(), cbar=False, yticklabels=False,cmap='viridis')
plt.xlabel("Name Of Columns")
plt.title("Places of missing values in column")
# Out:
# Text(0.5, 1.0, 'Places of missing values in column')

# %%
# Columns having missing values.
df1.isnull().sum().sort_values(ascending = False)[:6]
# Out:
# company               82137
# agent                 12193
# country                 452
# children                  4
# reserved_room_type        0
# assigned_room_type        0
# dtype: int64

# %%
# Filling/replacing null values with 0.
null_columns=['agent','children','company']
for col in null_columns:
  df1[col].fillna(0,inplace=True)


# Replacing NA values with 'others'
df1['country'].fillna('others',inplace=True)

# %%
#Successfully handled  Null Values
df1.isna().sum().sort_values(ascending=False)[:6].reset_index().rename(columns={'index':'Columns',0:'Null values'})
# Out:
#                        Columns  Null values
# 0                        hotel            0
# 1                  is_canceled            0
# 2           reservation_status            0
# 3    total_of_special_requests            0
# 4  required_car_parking_spaces            0
# 5                          adr            0

# %%
# droppping all 166 those rows in which addtion of of adlults ,children and babies is 0. That simply means  no bookings were made.
len(df1[df1['adults']+df1['babies']+df1['children']==0])
df1.drop(df1[df1['adults']+df1['babies']+df1['children']==0].index,inplace=True)

# %%
# Checking the unique values in categorical columns.
categorical_cols=list(set(df1.drop(columns=['reservation_status_date','country','arrival_date_month']).columns)-set(df1.describe()))
for col in categorical_cols:
  print(f'Unique values in column {col} are:, {(df1[col].unique())}')
# Out:
# Unique values in column market_segment are:, ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
#  'Undefined' 'Aviation']
# Unique values in column deposit_type are:, ['No Deposit' 'Refundable' 'Non Refund']
# Unique values in column reserved_room_type are:, ['C' 'A' 'D' 'E' 'G' 'F' 'H' 'L' 'B']
# Unique values in column hotel are:, ['Resort Hotel' 'City Hotel']
# Unique values in column assigned_room_type are:, ['C' 'A' 'D' 'E' 'G' 'F' 'I' 'B' 'H' 'L' 'K']
# Unique values in column reservation_status are:, ['Check-Out' 'Canceled' 'No-Show']
# Unique values in column customer_type are:, ['Transient' 'Contract' 'Transient-Party' 'Group']
# Unique values in column meal are:, ['BB' 'FB' 'HB' 'SC' 'Undefined']
# Unique values in column distribution_channel are:, ['Direct' 'Corporate' 'TA/TO' 'Undefined' 'GDS']

# %%
# lets add some new columns

df1['total_people'] = df1['adults'] + df1['babies'] + df1['children']   
df1['total_stay'] = df1['stays_in_weekend_nights'] + df1['stays_in_week_nights']

# %%
hotel_df_not_cancelled = hotel_df[hotel_df['is_canceled'] == 0]

# %% [markdown]
# ***1) What is the percentage of booking changes made by the customer?***

# %%
booking_changes_df=df1['booking_changes'].value_counts().reset_index().rename(columns={'index': "number_booking_changes",'booking_changes':'Counts'})

plt.figure(figsize=(10,6))
sns.barplot(x=booking_changes_df['number_booking_changes'],y=booking_changes_df['Counts']*100/df1.shape[0])
plt.title("% of Booking change")
plt.xlabel('Number of booking changes')
plt.ylabel('Percentage(%)')
# Out:
# Text(0, 0.5, 'Percentage(%)')

# %% [markdown]
# 0 = 0 changes made in the booking
#
# 1 = 1 change made in the booking
#
# 3 = 3 changes made in booking
#
#  **Observation**
#
#  Almost 84% of the bookings were not changed by guests.

# %% [markdown]
# ***2) Which type of food is mostly preferred by the guests?***

# %%
# df1['meal'].value_counts().plot.pie(explode=[0.05, 0.05,0.05,0.05,0.05], autopct='%1.1f%%', shadow=True, figsize=(20,15),fontsize=20)
plt.figure(figsize=(10,6))
sns.countplot(x=df1['meal'])
plt.xlabel('Meal Type')
plt.ylabel('Count')
plt.title("Preferred Meal Type")
# Out:
# Text(0.5, 1.0, 'Preferred Meal Type')

# %% [markdown]
# Types of meal in hotels:
#
#
#
# *  BB - Bed and Breakfast
# *  FB - Full Board
#
# *  HB - Half Board
# *  SC - Self Catering
#
#
#
# **Observation**
#
#  The mostly preferredmeals as per guests is
#
#  i)   BB - Bed and Breakfast
#
#  ii)  HB - Half Board  &  SC - Self Catering are equally preferred
#
# iii)   FB - Full Board

# %% [markdown]
# ***3) What is the percentage of cancellation?***

# %%
df1['is_canceled'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=20)
plt.title("Cancellation and non Cancellation")
# Out:
# Text(0.5, 1.0, 'Cancellation and non Cancellation')

# %% [markdown]
# **Observation**
#
# 27.5 % of the booking were cancelled

# %% [markdown]
# ***4) What is preferred stay in each hotel?***

# %%
not_canceled = df1[df1['is_canceled'] == 0]
s1 = not_canceled[not_canceled['total_stay'] < 15]
plt.figure(figsize = (10,5))
sns.countplot(x = s1['total_stay'], hue = s1['hotel'])
plt.show()

# %% [markdown]
# **Observation**
#
# Most common stay length is less than 4 days and generally people prefer City hotel for short stay, but for long stays, Resort Hotel is preferred.

# %% [markdown]
# **5) Visualizing proportion of booking cancellations wise bookings.**

# %%
a = hotel_df.groupby("hotel")['is_canceled'].describe()

sns.barplot(x=a.index, y=a["mean"] * 100)

# %% [markdown]
# **Observation**
#
# 43% of hotels were cancelled in city hotel
#
# 27% of resorts hotel booking cancelled

# %% [markdown]
# ***6) Market segment wise bookings***

# %%
plt.title("Segments wise booking")
ax = sns.countplot(x = "market_segment", data = hotel_df)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# **Observation**
#
# Indirect bookings through online and offline travel agents are higher compared to direct bookings and same is the case with group bookings which are also high.

# %% [markdown]
# ***7) From where the most guests are coming ?***

# %%
sns.barplot (y= list(hotel_df.country.value_counts().head (10)), x= list(hotel_df.country.value_counts().head(10).index))

# %% [markdown]
# **Observation**
#
# Around 40% of all bookings were booked from Portugal followed by Great Britain(10%) & France(8%).

# %%
ax= hotel_df.country.value_counts().head(10).plot (kind= 'bar');
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %% [markdown]
# PRT- Portugal
#
# GBR- United Kingdom
#
# FRA- France
#
# ESP- Spain
#
# DEU - Germany
#
# ITA -Itlay
#
# IRL - Ireland
#
# BEL -Belgium
#
# BRA -Brazil
#
# NLD-Netherlands

# %% [markdown]
# ***8) which channel is mostly used for early booking of hotels?***

# %%
group_by_dc = df1.groupby('distribution_channel')
d2 = pd.DataFrame(round(group_by_dc['lead_time'].median(),2)).reset_index().rename(columns = {'lead_time': 'median_lead_time'})
plt.figure(figsize = (7,5))
sns.barplot(x = d2['distribution_channel'], y = d2['median_lead_time'])
plt.show()

# %% [markdown]
# **Observation**
#
# TA/TO is mostly used for planning Hotel visits ahead of time. But for sudden visits other mediums are most preferred.

# %% [markdown]
# **9) which is the busiest month for hotels?**

# %%
# groupby arrival_date_month and taking the hotel count
bookings_by_months_df=df1.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':"Counts"})
# Create list of months in order
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
# creating df which will map the order of above months list without changing its values.
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)
# sorting by arrival_date_month
bookings_by_months_df=bookings_by_months_df.sort_values('arrival_date_month')

bookings_by_months_df
# Out:
#    arrival_date_month  Counts
# 4             January    4685
# 3            February    6083
# 7               March    7489
# 0               April    7900
# 8                 May    8344
# 6                June    7756
# 5                July   10043
# 1              August   11242
# 11          September    6682
# 10            October    6921
# 9            November    4973
# 2            December    5112

# %%
# set plot size
plt.figure(figsize=(14,6))

#pltting lineplot on x- months & y- booking counts
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['Counts'])

# set title for the plot
plt.title('Number of bookings across each month')
#set x label
plt.xlabel('Month')
#set y label
plt.ylabel('Number of bookings')
# Out:
# Text(0, 0.5, 'Number of bookings')

# %% [markdown]
# **Observation**
#
# July and August months had the most Bookings. Summer vaccation can be the reason for the bookings.

# %% [markdown]
# ***10) Which type of hotel is mostly prefered by the guests?***

# %%
df1['hotel'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=20)   
plt.title('Pie Chart for Most Preffered  Hotel')
# Out:
# Text(0.5, 1.0, 'Pie Chart for Most Preffered  Hotel')

# %% [markdown]
# **Observation**
#
# city hotel is mostly preferred by guest its around 61.1%
#
# Therefore city hotels has maximum bookings.

# %% [markdown]
# ***11) Which hotel has high chance that its customer will return for another stay?***

# %%
grouped_by_hotel = df1.groupby('hotel')

# %%
# Selecting and counting repeated customers bookings
repeated_data = df1[df1['is_repeated_guest'] == 1]
repeat_grp = repeated_data.groupby('hotel')
D1 = pd.DataFrame(repeat_grp.size()).rename(columns = {0:'total_repeated_guests'})

# Counting total bookings
total_booking = grouped_by_hotel.size()
D2 = pd.DataFrame(total_booking).rename(columns = {0: 'total_bookings'})
D3 = pd.concat([D1,D2], axis = 1)

# Calculating repeat %
D3['repeat_%'] = round((D3['total_repeated_guests']/D3['total_bookings'])*100,2)

plt.figure(figsize = (10,5))
sns.barplot(x = D3.index, y = D3['repeat_%'])
plt.show()

# %% [markdown]
# **Observation**
#
# Both hotels have very small percentage that customer will repeat, but Resort hotel has slightly higher repeat % than City Hotel.

# %% [markdown]
# ***12) Which hotel has longer waiting time?***

# %%
d5 = pd.DataFrame(grouped_by_hotel['days_in_waiting_list'].agg(np.mean).reset_index().rename(columns = {'days_in_waiting_list':'avg_waiting_period'}))
plt.figure(figsize = (8,5))
sns.barplot(x = d5['hotel'], y = d5['avg_waiting_period'] )
plt.show()

# %% [markdown]
# ***13) What is the percentage distribution of required car parking spaces?***

# %%
df1['required_car_parking_spaces'].value_counts().plot.pie(explode=[0.05]*5, autopct='%1.1f%%',shadow=False,figsize=(12,8),fontsize=15,labels=None)

labels=df1['required_car_parking_spaces'].value_counts().index
plt.title('% Distribution of required car parking spaces')
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# **Observation**
#
# Observation
# 91.6 % guests did not required the parking space. only 8.3 % guests required only 1 parking space.

# %% [markdown]
# ***14) which hotel seems to make more revenue?***

# %%
d3 = grouped_by_hotel['adr'].agg(np.mean).reset_index().rename(columns = {'adr':'avg_adr'})   # calculating average adr
plt.figure(figsize = (8,5))
sns.barplot(x = d3['hotel'], y = d3['avg_adr'] )
plt.show()

# %% [markdown]
# **Observation**
#
# Avg adr of Resort hotel is slightly lower than that of City hotel. Hence, City hotel seems to be making slightly more revenue.

# %% [markdown]
# ***15) Which year had the highest bookings?***

# %%
# set plot size
plt.figure(figsize=(12,8))

#  plot with countplot
sns.countplot(x=df1['arrival_date_year'],hue=df1['hotel'])
plt.title("Year Wise bookings")
# Out:
# Text(0.5, 1.0, 'Year Wise bookings')

# %% [markdown]
# **Observation**
#
# 2016 had the higest bookings.
#
# 2015 had less 7000 bookings.
#
# overall City hotels had the most of the bookings.
